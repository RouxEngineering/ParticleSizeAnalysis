# %% [markdown]
# # Data Visualization

# %% [markdown]
# This program will take particle data and calculate the effective Diameter (Deff) and plot it against the percent Particle number.
#
# This program also experiments with pandas

# %% [markdown]
# * Attribute = characterisitc of a data type (no brackets)
# * Methods = Function that preforms action with data type (brackets requried)

# %% [markdown]
# ### Import Particle Data via pandas

# %%
# Import statements, set alias
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os
import numpy as np

# %%
# Define File path
file_path = "Ti64_lot232_results2.csv"

# Check if path exist
if os.path.exists(file_path): print("File path exists")
else: print("Error, file doesn't exist.")

# Open CVS file from Local Comupter 
particle_data = pd.read_csv(file_path)

# Using the head method to visualize data
particle_data.head(8)
# Out:
# File path exists
#         Area  Mean  StdDev  Min  Max         X         Y        XM        YM  \
# 0  1  84.661   255       0  255  255  1696.501   111.422  1696.501   111.422
# 1  2  21.403   255       0  255  255     1.126   200.943     1.126   200.943
# 2  3  30.440   255       0  255  255  1458.362   343.610  1458.362   343.610
# 3  4  60.880   255       0  255  255   166.455   579.844   166.455   579.844
# 4  5  98.930   255       0  255  255  1510.710   628.959  1510.710   628.959
# 5  6  20.452   255       0  255  255   793.913   755.581   793.913   755.581
# 6  7  37.099   255       0  255  255  1233.484  1137.993  1233.484  1137.993
# 7  8  63.734   255       0  255  255  1510.659  1332.383  1510.659  1332.383
#
#    Perim.   Feret  Median  FeretX  FeretY  FeretAngle  MinFeret
# 0  48.068  18.050     255    2461     174      83.418     7.586
# 1  36.866  15.922     255       0     279      94.970     2.069
# 2  22.334   8.305     255    2110     494     131.634     6.122
# 3  32.896  10.795     255     238     848      63.435     8.944
# 4  38.747  12.660     255    2182     908     150.642    11.034
# 5  16.650   6.168     255    1147    1098      26.565     4.828
# 6  22.502   8.072     255    1783    1648     160.017     6.761
# 7  53.112  15.313     255    2184    1923     125.838     8.966

# %%
# Check the data type of each column , with attribute (no brakets)
particle_data.dtypes
# Out:
#                 int64
# Area          float64
# Mean            int64
# StdDev          int64
# Min             int64
# Max             int64
# X             float64
# Y             float64
# XM            float64
# YM            float64
# Perim.        float64
# Feret         float64
# Median          int64
# FeretX          int64
# FeretY          int64
# FeretAngle    float64
# MinFeret      float64
# dtype: object

# %% [markdown]
# ### Filter the Data: selecting Specific rows and columns from a DataFrame

# %%
# One column in a DataFrame is a Series data type
type(particle_data["Area"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Indexing data

# %%
# loc/iloc[row(s), column(s)]

# loc = when using column names and row labels / condition expression

# iloc = index values

particle_data.iloc[0:13, 0:15]
# Out:
#           Area  Mean  StdDev  Min  Max         X         Y        XM  \
# 0    1  84.661   255       0  255  255  1696.501   111.422  1696.501
# 1    2  21.403   255       0  255  255     1.126   200.943     1.126
# 2    3  30.440   255       0  255  255  1458.362   343.610  1458.362
# 3    4  60.880   255       0  255  255   166.455   579.844   166.455
# 4    5  98.930   255       0  255  255  1510.710   628.959  1510.710
# 5    6  20.452   255       0  255  255   793.913   755.581   793.913
# 6    7  37.099   255       0  255  255  1233.484  1137.993  1233.484
# 7    8  63.734   255       0  255  255  1510.659  1332.383  1510.659
# 8    9  76.100   255       0  255  255  1520.875  1332.009  1520.875
# 9   10  75.149   255       0  255  255  1531.379  1332.069  1531.379
# 10  11  65.161   255       0  255  255  1546.970  1335.109  1546.970
# 11  12  84.661   255       0  255  255  1561.666  1333.313  1561.666
# 12  13  29.013   255       0  255  255   249.469  1416.750   249.469
#
#           YM  Perim.   Feret  Median  FeretX  FeretY
# 0    111.422  48.068  18.050     255    2461     174
# 1    200.943  36.866  15.922     255       0     279
# 2    343.610  22.334   8.305     255    2110     494
# 3    579.844  32.896  10.795     255     238     848
# 4    628.959  38.747  12.660     255    2182     908
# 5    755.581  16.650   6.168     255    1147    1098
# 6   1137.993  22.502   8.072     255    1783    1648
# 7   1332.383  53.112  15.313     255    2184    1923
# 8   1332.009  38.245  13.964     255    2202    1941
# 9   1332.069  37.674  13.964     255    2217    1941
# 10  1335.109  56.176  15.498     255    2237    1946
# 11  1333.313  71.851  17.033     255    2254    1927
# 12  1416.750  31.418  14.499     255     350    2055

# %% [markdown]
# ### Create new column for effective Diameter

# %%
# Create and show an effective radius column
# A = PI * r^2 
particle_data["eff_radius"] = ( particle_data["Area"] / math.pi ) ** 1/2  # r = (A/PI)^0.5
print("Show radius column: \n", particle_data["eff_radius"])
print(" ")

# Create a Diameter Column
particle_data["eff_diameter"] = particle_data["eff_radius"] * 2
print("Show diameter column: \n", particle_data["eff_diameter"])
# print("Square root of 4:, ", 4 ** 1/2)
# Out:
# Show radius column:
#  0     13.474217
# 1      3.406393
# 2      4.844676
# 3      9.689353
# 4     15.745199
# 5      3.255037
# 6      5.904489
# 7     10.143581
# 8     12.111691
# 9     11.960335
# 10    10.370695
# 11    13.474217
# 12     4.617562
# Name: eff_radius, dtype: float64
#
# Show diameter column:
#  0     26.948433
# 1      6.812786
# 2      9.689353
# 3     19.378706
# 4     31.490397
# 5      6.510074
# 6     11.808978
# 7     20.287162
# 8     24.223382
# 9     23.920670
# 10    20.741390
# 11    26.948433
# 12     9.235125
# Name: eff_diameter, dtype: float64

# %%
particle_data
# Out:
#           Area  Mean  StdDev  Min  Max         X         Y        XM  \
# 0    1  84.661   255       0  255  255  1696.501   111.422  1696.501
# 1    2  21.403   255       0  255  255     1.126   200.943     1.126
# 2    3  30.440   255       0  255  255  1458.362   343.610  1458.362
# 3    4  60.880   255       0  255  255   166.455   579.844   166.455
# 4    5  98.930   255       0  255  255  1510.710   628.959  1510.710
# 5    6  20.452   255       0  255  255   793.913   755.581   793.913
# 6    7  37.099   255       0  255  255  1233.484  1137.993  1233.484
# 7    8  63.734   255       0  255  255  1510.659  1332.383  1510.659
# 8    9  76.100   255       0  255  255  1520.875  1332.009  1520.875
# 9   10  75.149   255       0  255  255  1531.379  1332.069  1531.379
# 10  11  65.161   255       0  255  255  1546.970  1335.109  1546.970
# 11  12  84.661   255       0  255  255  1561.666  1333.313  1561.666
# 12  13  29.013   255       0  255  255   249.469  1416.750   249.469
#
#           YM  Perim.   Feret  Median  FeretX  FeretY  FeretAngle  MinFeret  \
# 0    111.422  48.068  18.050     255    2461     174      83.418     7.586
# 1    200.943  36.866  15.922     255       0     279      94.970     2.069
# 2    343.610  22.334   8.305     255    2110     494     131.634     6.122
# 3    579.844  32.896  10.795     255     238     848      63.435     8.944
# 4    628.959  38.747  12.660     255    2182     908     150.642    11.034
# 5    755.581  16.650   6.168     255    1147    1098      26.565     4.828
# 6   1137.993  22.502   8.072     255    1783    1648     160.017     6.761
# 7   1332.383  53.112  15.313     255    2184    1923     125.838     8.966
# 8   1332.009  38.245  13.964     255    2202    1941      69.775     9.655
# 9   1332.069  37.674  13.964     255    2217    1941      69.775     8.966
# 10  1335.109  56.176  15.498     255    2237    1946      57.724    10.345
# 11  1333.313  71.851  17.033     255    2254    1927     148.241     9.655
# 12  1416.750  31.418  14.499     255     350    2055     177.274     2.759
#
#     eff_radius  eff_diameter
# 0    13.474217     26.948433
# 1     3.406393      6.812786
# 2     4.844676      9.689353
# 3     9.689353     19.378706
# 4    15.745199     31.490397
# 5     3.255037      6.510074
# 6     5.904489     11.808978
# 7    10.143581     20.287162
# 8    12.111691     24.223382
# 9    11.960335     23.920670
# 10   10.370695     20.741390
# 11   13.474217     26.948433
# 12    4.617562      9.235125

# %% [markdown]
# # Cumulative Percentage:
# * Calculate Cumulative percentage: (number of particles smaller than or equal to a given size/ total particles ) x 100

# %%
# Rename columns
particle_data1 = particle_data.rename( columns= {" ":"particle_number",
                                                 "eff_radius":"eff_radius_microns",
                                                "eff_diameter":"eff_diameter_microns"})

# Create a percent particle column
total_particles =list(particle_data1["particle_number"])[-1] # Grab length of list
print("total numnber of particles in this dataset: ", total_particles)

# Sort the data: ascending order, effective diameter (microns)
particle_data1 = particle_data1.sort_values(by="eff_diameter_microns")

cumulative_percentages = (np.arange(1, total_particles +1) / total_particles) * 100 
print("cumulative percentages (%):", cumulative_percentages)

particle_data1["cumulative_particle_percentage"] = cumulative_percentages
# Out:
# total numnber of particles in this dataset:  13
# cumulative percentages (%): [  7.69230769  15.38461538  23.07692308  30.76923077  38.46153846
#   46.15384615  53.84615385  61.53846154  69.23076923  76.92307692
#   84.61538462  92.30769231 100.        ]

# %%
particle_data1
# Out:
#     particle_number    Area  Mean  StdDev  Min  Max         X         Y  \
# 5                 6  20.452   255       0  255  255   793.913   755.581
# 1                 2  21.403   255       0  255  255     1.126   200.943
# 12               13  29.013   255       0  255  255   249.469  1416.750
# 2                 3  30.440   255       0  255  255  1458.362   343.610
# 6                 7  37.099   255       0  255  255  1233.484  1137.993
# 3                 4  60.880   255       0  255  255   166.455   579.844
# 7                 8  63.734   255       0  255  255  1510.659  1332.383
# 10               11  65.161   255       0  255  255  1546.970  1335.109
# 9                10  75.149   255       0  255  255  1531.379  1332.069
# 8                 9  76.100   255       0  255  255  1520.875  1332.009
# 0                 1  84.661   255       0  255  255  1696.501   111.422
# 11               12  84.661   255       0  255  255  1561.666  1333.313
# 4                 5  98.930   255       0  255  255  1510.710   628.959
#
#           XM        YM  Perim.   Feret  Median  FeretX  FeretY  FeretAngle  \
# 5    793.913   755.581  16.650   6.168     255    1147    1098      26.565
# 1      1.126   200.943  36.866  15.922     255       0     279      94.970
# 12   249.469  1416.750  31.418  14.499     255     350    2055     177.274
# 2   1458.362   343.610  22.334   8.305     255    2110     494     131.634
# 6   1233.484  1137.993  22.502   8.072     255    1783    1648     160.017
# 3    166.455   579.844  32.896  10.795     255     238     848      63.435
# 7   1510.659  1332.383  53.112  15.313     255    2184    1923     125.838
# 10  1546.970  1335.109  56.176  15.498     255    2237    1946      57.724
# 9   1531.379  1332.069  37.674  13.964     255    2217    1941      69.775
# 8   1520.875  1332.009  38.245  13.964     255    2202    1941      69.775
# 0   1696.501   111.422  48.068  18.050     255    2461     174      83.418
# 11  1561.666  1333.313  71.851  17.033     255    2254    1927     148.241
# 4   1510.710   628.959  38.747  12.660     255    2182     908     150.642
#
#     MinFeret  eff_radius_microns  eff_diameter_microns  \
# 5      4.828            3.255037              6.510074
# 1      2.069            3.406393              6.812786
# 12     2.759            4.617562              9.235125
# 2      6.122            4.844676              9.689353
# 6      6.761            5.904489             11.808978
# 3      8.944            9.689353             19.378706
# 7      8.966           10.143581             20.287162
# 10    10.345           10.370695             20.741390
# 9      8.966           11.960335             23.920670
# 8      9.655           12.111691             24.223382
# 0      7.586           13.474217             26.948433
# 11     9.655           13.474217             26.948433
# 4     11.034           15.745199             31.490397
#
#     cumulative_particle_percentage
# 5                         7.692308
# 1                        15.384615
# 12                       23.076923
# 2                        30.769231
# 6                        38.461538
# 3                        46.153846
# 7                        53.846154
# 10                       61.538462
# 9                        69.230769
# 8                        76.923077
# 0                        84.615385
# 11                       92.307692
# 4                       100.000000

# %%
distribution_data = particle_data1.iloc[:, -2:]
distribution_data
# Out:
#     eff_diameter_microns  cumulative_particle_percentage
# 5               6.510074                        7.692308
# 1               6.812786                       15.384615
# 12              9.235125                       23.076923
# 2               9.689353                       30.769231
# 6              11.808978                       38.461538
# 3              19.378706                       46.153846
# 7              20.287162                       53.846154
# 10             20.741390                       61.538462
# 9              23.920670                       69.230769
# 8              24.223382                       76.923077
# 0              26.948433                       84.615385
# 11             26.948433                       92.307692
# 4              31.490397                      100.000000

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Relatinship Plot: Cumulative particle % vs. effective diameter (microns)

# %%
# Apply default theme of Seaborn
sns.set_theme()

# Create a relationaship visualization
sns.relplot(
    data= distribution_data,
    x="eff_diameter_microns", y="cumulative_particle_percentage",
    kind="line",
)

# %% [markdown]
# ### Distriubution plot: Boxplot of the effective diameter (microns)

# %%
sns.boxplot(
    data = distribution_data["eff_diameter_microns"],
    orient= "h"
)
# Out:
# <Axes: xlabel='eff_diameter_microns'>

# %%
# Histogram
sns.displot(
    data= particle_data1,
    x="eff_diameter_microns",
    # kind = "kde"
)

# %% [markdown]
# # Next Steps
# 1. Pandas sorting: https://pandas.pydata.org/docs/user_guide/basics.html#sorting
# 2. Axes-level and Figure-level plot differences
